# %%
import pandas as pd
import MetaTrader5 as mt5
from datetime import datetime
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
import vectorbt as vbt
import numpy as np

# %%
mt5.initialize()
# Out:
# True

# %%
start_date = datetime(2024, 1, 1)
end_date = datetime(2025, 10, 31)
timeframe = mt5.TIMEFRAME_H1

asset = "EURUSD"

price_df = mt5.copy_rates_range(asset, timeframe, start_date, end_date)
assert price_df.shape[0] > 0
price_df = pd.DataFrame(price_df)

price_df.loc[:, "time_dt"] = pd.to_datetime(price_df.time, unit="s")
price_df.loc[:, "week"] = price_df.loc[:, "time_dt"].apply(lambda date: date.isocalendar()[1])

price_df = price_df.sort_index()

o, h, l, c = (price_df['open'], price_df['high'], price_df['low'], price_df['close'])
o_1, h_1, l_1, c_1 = o.shift(1), h.shift(1), l.shift(1), c.shift(1)

# Your logic applied at t using (t) and (t-1)
bull_order_block = (c > o) & (o_1 > c_1) & (h > h_1)
bear_order_block = (c < o) & (o_1 > c_1) & (l < l_1)

cross_pivot_low = price_df.low.vbt.crossed_below(price_df.low.rolling(40).min().shift(1))
cross_pivot_low_last_n = cross_pivot_low.rolling(3).apply(lambda x: np.any(x), raw=True)
bool_ts = (cross_pivot_low_last_n.astype(bool) & bull_order_block)

short_sma = 8*24
long_sma = 50*24

short_sma_ts = price_df.close.rolling(short_sma).mean()
long_sma_ts = price_df.close.rolling(long_sma).mean()

bool_ts = bool_ts & (short_sma_ts > long_sma_ts)

# Compute TP and SL based on first 10% historical data
mean_two_hour_move = price_df.close.rolling(2).apply(lambda x: abs(x[-1]-x[0])/x[0], raw=True).describe()
mean_two_hour_move = mean_two_hour_move["mean"]

sl = mean_two_hour_move
rr = 5
tp = sl*3

pf = vbt.Portfolio.from_signals(close=price_df.close, entries=bool_ts, sl_stop=sl, tp_stop=tp, freq="h")

# %%
import pandas as pd
import numpy as np
import MetaTrader5 as mt5
import vectorbt as vbt
from datetime import datetime
import matplotlib.pyplot as plt



def load_data(symbol=SYMBOL, start=START_DATE, end=END_DATE, tf=TIMEFRAME):
    """Load OHLC data from MT5"""
    df = mt5.copy_rates_range(symbol, tf, start, end)
    assert df.shape[0] > 0, f"No data for {symbol}"
    df = pd.DataFrame(df)
    df['time_dt'] = pd.to_datetime(df.time, unit="s")
    return df.sort_index()

def add_indicators(df, sma_short=SMA_SHORT_HOURS, sma_long=SMA_LONG_HOURS, pivot_window=PIVOT_WINDOW):
    """Add technical indicators"""
    df['sma_short'] = df.close.rolling(sma_short).mean()
    df['sma_long'] = df.close.rolling(sma_long).mean()
    df['pivot_low'] = df.low.rolling(pivot_window).min().shift(1)
    df['uptrend'] = df.sma_short > df.sma_long
    return df

def get_order_blocks(df):
    """Calculate order block patterns"""
    o, h, l, c = df['open'], df['high'], df['low'], df['close']
    o_1, h_1, l_1, c_1 = o.shift(1), h.shift(1), l.shift(1), c.shift(1)

    df['bull_ob'] = (c > o) & (o_1 > c_1) & (h > h_1)
    df['bear_ob'] = (c < o) & (o_1 > c_1) & (l < l_1)
    return df

def generate_signals(df, lookback=BREAKOUT_LOOKBACK):
    """Generate entry signals"""
    # Pivot breakout
    cross_pivot = df.low.vbt.crossed_below(df.pivot_low)
    cross_recent = cross_pivot.rolling(lookback).apply(lambda x: np.any(x), raw=True).astype(bool)

    # Combine all conditions
    df['long_signal'] = cross_recent & df.bull_ob & df.uptrend
    df['short_signal'] = False  # Add short logic if needed

    return df

def calculate_stops(df, atr_period=ATR_PERIOD, sl_mult=SL_MULTIPLIER, tp_mult=TP_MULTIPLIER):
    """Calculate dynamic stops"""
    atr = df.close.rolling(atr_period).apply(
        lambda x: abs(x[-1] - x[0]) / x[0], raw=True
    ).mean()
    return atr * sl_mult, atr * tp_mult

def run_backtest(df, sl, tp, init_cash=10000, size=1000, fees=0.0002):
    """Run vectorbt backtest"""
    return vbt.Portfolio.from_signals(
        close=df.close,
        entries=df.long_signal,
        sl_stop=sl,
        tp_stop=tp,
        freq="h",
        init_cash=init_cash,
        size=size,
        fees=fees
    )

def plot_results(df, pf):
    """Quick visualization"""
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8), sharex=True)

    # Price and signals
    ax1.plot(df.index, df.close, 'b-', alpha=0.6, label='Close')
    ax1.plot(df.index, df.sma_short, 'g--', alpha=0.5, label=f'SMA {SMA_SHORT_HOURS}h')
    ax1.plot(df.index, df.sma_long, 'r--', alpha=0.5, label=f'SMA {SMA_LONG_HOURS}h')
    ax1.scatter(df.index[df.long_signal], df.close[df.long_signal],
                marker='^', c='lime', s=100, zorder=5, label='Long Signal')
    ax1.legend(loc='upper left')
    ax1.set_ylabel('Price')
    ax1.grid(True, alpha=0.3)

    # Portfolio value
    ax2.plot(pf.value(), 'k-', label='Portfolio Value')
    ax2.fill_between(pf.value().index, pf.value().values, alpha=0.3)
    ax2.set_ylabel('Portfolio Value')
    ax2.set_xlabel('Date')
    ax2.grid(True, alpha=0.3)
    ax2.legend()

    plt.tight_layout()
    plt.show()

def print_stats(pf):
    """Print performance metrics"""
    print(f"Total Return: {pf.total_return():.2%}")
    print(f"Sharpe Ratio: {pf.sharpe_ratio():.2f}")
    print(f"Max Drawdown: {pf.max_drawdown():.2%}")
    print(f"Win Rate: {pf.win_rate():.2%}")
    print(f"Total Trades: {pf.total_trades()}")
    print(f"Profit Factor: {pf.profit_factor():.2f}")

# Main pipeline
def run_strategy():
    """Run complete strategy pipeline"""
    # Load and prepare data


    # Calculate stops
    sl, tp = calculate_stops(df)

    # Run backtest
    pf = run_backtest(df, sl, tp)

    # Results
    print_stats(pf)
    plot_results(df, pf)

    return df, pf

# %%
# Backtest parameters
SYMBOL = "EURUSD"
START_DATE = datetime(2024, 1, 1)
END_DATE = datetime(2025, 10, 31)
TIMEFRAME = mt5.TIMEFRAME_H1

# Strategy parameters
PIVOT_WINDOW = 40
BREAKOUT_LOOKBACK = 3
SMA_SHORT_HOURS = 8 * 24
SMA_LONG_HOURS = 50 * 24

# Risk parameters
ATR_PERIOD = 2
SL_MULTIPLIER = 1.0
TP_MULTIPLIER = 3.0

# %%
df = load_data()
df = add_indicators(df)
df = get_order_blocks(df)
df = generate_signals(df)

vbt.Portfolio.from_signals(
        close=df.close,
        entries=df.long_signal,
        sl_stop=sl,
        tp_stop=tp,
        freq="h",
        init_cash=100000,
    )

# %%
import vectorbt as vbt

# %%
pf.stats()
# Out:
# Start                                                 0
# End                                               11423
# Period                                476 days 00:00:00
# Start Value                                       100.0
# End Value                                    103.248425
# Total Return [%]                               3.248425
# Benchmark Return [%]                           4.756687
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                     0.0
# Max Drawdown [%]                               1.319414
# Max Drawdown Duration                 182 days 23:00:00
# Total Trades                                         62
# Total Closed Trades                                  62
# Total Open Trades                                     0
# Open Trade PnL                                      0.0
# Win Rate [%]                                  41.935484
# Best Trade [%]                                 1.167182
# Worst Trade [%]                               -0.629176
# Avg Winning Trade [%]                          0.300322
# Avg Losing Trade [%]                          -0.127526
# Avg Winning Trade Duration    0 days 10:32:18.461538461
# Avg Losing Trade Duration               0 days 07:03:20
# Profit Factor                                  1.703493
# Expectancy                                     0.052394
# Sharpe Ratio                                   1.400796
# Calmar Ratio                                   1.880838
# Omega Ratio                                    1.290753
# Sortino Ratio                                  2.497051
# dtype: object

# %%
pf.plot_trades()
# Out:
# FigureWidget({
#     'data': [{'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'c204aebd-b4f8-4176-a07b-5bd74277f2d8',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1.10434, 1.10364, 1.10381, ..., 1.15642, 1.15695, 1.15687])},
#              {'customdata': array([[0, 0, 91.8189330639978, 0.0, 'Long'],
#                                    [1, 1, 92.16786448882249, 0.0, 'Long'],
#                                    [2, 2, 92.27777578550895, 0.0, 'Long'],
#                                    ...,
#                                    [59, 59, 88.00140789109798, 0.0, 'Long'],
#                                    [60, 60, 88.43559799346771, 0.0, 'Long'],
#                                    [61, 61, 88.911453057241, 0.0, 'Long']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'br>Direction: %{customdata[4]}'),
#               'marker': {'color': '#4285F4',
#                          'line': {'color': 'rgb(11,84,205)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Entry',
#               'type': 'scatter',
#               'uid': '8e75515b-ff38-4ef5-ac6d-c60f23ab274a',
#               'x': array([ 1269,  1399,  1490,  2416,  2446,  2555,  2562,  2571,  2576,  2745,
#                            2749,  2777,  3439,  3474,  3617,  3660,  3784,  4145,  4178,  4213,
#                            4314,  4361,  4482,  4547,  4736,  4746,  4771,  6760,  7052,  7068,
#                            7556,  7628,  7672,  8288,  8298,  8399,  8468,  8660,  8743,  8745,
#                            8864,  8962,  9095,  9130,  9350,  9423,  9449,  9537,  9592,  9614,
#                            9759,  9795,  9807,  9832,  9876, 10283, 10539, 10573, 10719, 10821,
#                           11028, 11061], dtype=int64),
#               'y': array([1.0891 , 1.08415, 1.08175, 1.08593, 1.08219, 1.08516, 1.08153, 1.07983,
#                           1.07955, 1.07644, 1.07536, 1.07323, 1.08886, 1.08862, 1.08087, 1.07843,
#                           1.09063, 1.10848, 1.10535, 1.10362, 1.10488, 1.10121, 1.11243, 1.11058,
#                           1.10377, 1.10303, 1.09679, 1.03964, 1.04452, 1.04247, 1.09079, 1.08051,
#                           1.07907, 1.13023, 1.12905, 1.13095, 1.10895, 1.1278 , 1.13147, 1.13266,
#                           1.13779, 1.14082, 1.14807, 1.14765, 1.17566, 1.17351, 1.17066, 1.16855,
#                           1.15927, 1.1587 , 1.17217, 1.1591 , 1.15461, 1.14804, 1.14121, 1.16425,
#                           1.16995, 1.16836, 1.17583, 1.16607, 1.16338, 1.15596])},
#              {'customdata': array([[4, 4, 92.00625850160866, ..., 0.0022177251684085144, 'Long',
#                                     '0 days 13:00:00'],
#                                    [8, 8, 92.17222040126009, ..., 0.0031031448288639015, 'Long',
#                                     '0 days 06:00:00'],
#                                    [11, 11, 92.8298816224941, ..., 0.0024412288139543338, 'Long',
#                                     '0 days 19:00:00'],
#                                    ...,
#                                    [57, 57, 87.66882084691, ..., 0.002678968810982864, 'Long',
#                                     '0 days 01:00:00'],
#                                    [59, 59, 88.00140789109798, ..., 0.0026156234188342104, 'Long',
#                                     '0 days 19:00:00'],
#                                    [61, 61, 88.911453057241, ..., 0.0045762829163638625, 'Long',
#                                     '0 days 20:00:00']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Exit - Profit',
#               'type': 'scatter',
#               'uid': '90b80259-604c-47a2-a3d1-91ff918b5651',
#               'x': array([ 2459,  2582,  2796,  3636,  3682,  3832,  4215,  4383,  4484,  4551,
#                            6762,  8292,  8477,  8667,  8870,  8967,  9102,  9353,  9593,  9624,
#                            9767,  9878, 10552, 10574, 10840, 11081], dtype=int64),
#               'y': array([1.08459, 1.0829 , 1.07585, 1.08331, 1.08145, 1.09311, 1.1061 , 1.10368,
#                           1.11489, 1.11293, 1.04199, 1.1332 , 1.11164, 1.13139, 1.14092, 1.14429,
#                           1.15056, 1.17892, 1.16295, 1.16165, 1.17601, 1.15453, 1.17276, 1.17149,
#                           1.16912, 1.16125])},
#              {'customdata': array([[0, 0, 91.8189330639978, ..., -0.0007620971444310953, 'Long',
#                                     '0 days 04:00:00'],
#                                    [1, 1, 92.16786448882249, ..., -0.0010238435640824238, 'Long',
#                                     '0 days 01:00:00'],
#                                    [2, 2, 92.27777578550895, ..., -0.0015530390570833367, 'Long',
#                                     '0 days 07:00:00'],
#                                    ...,
#                                    [55, 55, 87.83389497747368, ..., -0.0007558514064847318, 'Long',
#                                     '0 days 16:00:00'],
#                                    [58, 58, 87.34523437397122, ..., -0.000850463077145494, 'Long',
#                                     '0 days 05:00:00'],
#                                    [60, 60, 88.43559799346771, ..., -0.0010314772473311521, 'Long',
#                                     '0 days 04:00:00']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Exit - Loss',
#               'type': 'scatter',
#               'uid': 'a3aada42-9a17-41ab-a02f-d25a6176be79',
#               'x': array([ 1273,  1400,  1497,  2434,  2559,  2564,  2575,  2746,  2750,  3442,
#                            3489,  4149,  4211,  4317,  4744,  4766,  4787,  7066,  7073,  7557,
#                            7636,  7673,  8306,  8400,  8744,  8749,  9137,  9426,  9469,  9545,
#                            9797,  9808,  9833, 10299, 10724, 11032], dtype=int64),
#               'y': array([1.08827, 1.08304, 1.08007, 1.08486, 1.08383, 1.08059, 1.07901, 1.07567,
#                           1.07413, 1.0879 , 1.08761, 1.10758, 1.104  , 1.10381, 1.10171, 1.09609,
#                           1.09587, 1.04289, 1.04046, 1.08988, 1.07964, 1.07807, 1.12822, 1.13013,
#                           1.13044, 1.13177, 1.14601, 1.1694 , 1.16911, 1.16712, 1.15828, 1.15228,
#                           1.14688, 1.16337, 1.17483, 1.16218])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2446,
#                            'x1': 2459,
#                            'xref': 'x',
#                            'y0': 1.08219,
#                            'y1': 1.08459,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2576,
#                            'x1': 2582,
#                            'xref': 'x',
#                            'y0': 1.07955,
#                            'y1': 1.0829,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2777,
#                            'x1': 2796,
#                            'xref': 'x',
#                            'y0': 1.07323,
#                            'y1': 1.07585,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 3617,
#                            'x1': 3636,
#                            'xref': 'x',
#                            'y0': 1.08087,
#                            'y1': 1.08331,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 3660,
#                            'x1': 3682,
#                            'xref': 'x',
#                            'y0': 1.07843,
#                            'y1': 1.08145,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 3784,
#                            'x1': 3832,
#                            'xref': 'x',
#                            'y0': 1.09063,
#                            'y1': 1.09311,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4213,
#                            'x1': 4215,
#                            'xref': 'x',
#                            'y0': 1.10362,
#                            'y1': 1.1061,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4361,
#                            'x1': 4383,
#                            'xref': 'x',
#                            'y0': 1.10121,
#                            'y1': 1.10368,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4482,
#                            'x1': 4484,
#                            'xref': 'x',
#                            'y0': 1.11243,
#                            'y1': 1.11489,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4547,
#                            'x1': 4551,
#                            'xref': 'x',
#                            'y0': 1.11058,
#                            'y1': 1.11293,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 6760,
#                            'x1': 6762,
#                            'xref': 'x',
#                            'y0': 1.03964,
#                            'y1': 1.04199,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8288,
#                            'x1': 8292,
#                            'xref': 'x',
#                            'y0': 1.13023,
#                            'y1': 1.1332,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8468,
#                            'x1': 8477,
#                            'xref': 'x',
#                            'y0': 1.10895,
#                            'y1': 1.11164,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8660,
#                            'x1': 8667,
#                            'xref': 'x',
#                            'y0': 1.1278,
#                            'y1': 1.1313900000000001,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8864,
#                            'x1': 8870,
#                            'xref': 'x',
#                            'y0': 1.13779,
#                            'y1': 1.14092,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8962,
#                            'x1': 8967,
#                            'xref': 'x',
#                            'y0': 1.14082,
#                            'y1': 1.14429,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9095,
#                            'x1': 9102,
#                            'xref': 'x',
#                            'y0': 1.14807,
#                            'y1': 1.15056,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9350,
#                            'x1': 9353,
#                            'xref': 'x',
#                            'y0': 1.17566,
#                            'y1': 1.17892,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9592,
#                            'x1': 9593,
#                            'xref': 'x',
#                            'y0': 1.15927,
#                            'y1': 1.16295,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9614,
#                            'x1': 9624,
#                            'xref': 'x',
#                            'y0': 1.1587,
#                            'y1': 1.16165,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9759,
#                            'x1': 9767,
#                            'xref': 'x',
#                            'y0': 1.17217,
#                            'y1': 1.17601,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9876,
#                            'x1': 9878,
#                            'xref': 'x',
#                            'y0': 1.14121,
#                            'y1': 1.15453,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 10539,
#                            'x1': 10552,
#                            'xref': 'x',
#                            'y0': 1.16995,
#                            'y1': 1.17276,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 10573,
#                            'x1': 10574,
#                            'xref': 'x',
#                            'y0': 1.16836,
#                            'y1': 1.17149,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 10821,
#                            'x1': 10840,
#                            'xref': 'x',
#                            'y0': 1.16607,
#                            'y1': 1.16912,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 11061,
#                            'x1': 11081,
#                            'xref': 'x',
#                            'y0': 1.1559599999999999,
#                            'y1': 1.16125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 1269,
#                            'x1': 1273,
#                            'xref': 'x',
#                            'y0': 1.0891,
#                            'y1': 1.08827,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 1399,
#                            'x1': 1400,
#                            'xref': 'x',
#                            'y0': 1.08415,
#                            'y1': 1.08304,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 1490,
#                            'x1': 1497,
#                            'xref': 'x',
#                            'y0': 1.08175,
#                            'y1': 1.08007,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2416,
#                            'x1': 2434,
#                            'xref': 'x',
#                            'y0': 1.08593,
#                            'y1': 1.08486,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2555,
#                            'x1': 2559,
#                            'xref': 'x',
#                            'y0': 1.08516,
#                            'y1': 1.08383,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2562,
#                            'x1': 2564,
#                            'xref': 'x',
#                            'y0': 1.08153,
#                            'y1': 1.08059,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2571,
#                            'x1': 2575,
#                            'xref': 'x',
#                            'y0': 1.07983,
#                            'y1': 1.07901,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2745,
#                            'x1': 2746,
#                            'xref': 'x',
#                            'y0': 1.07644,
#                            'y1': 1.07567,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 2749,
#                            'x1': 2750,
#                            'xref': 'x',
#                            'y0': 1.07536,
#                            'y1': 1.07413,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 3439,
#                            'x1': 3442,
#                            'xref': 'x',
#                            'y0': 1.08886,
#                            'y1': 1.0879,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 3474,
#                            'x1': 3489,
#                            'xref': 'x',
#                            'y0': 1.08862,
#                            'y1': 1.08761,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4145,
#                            'x1': 4149,
#                            'xref': 'x',
#                            'y0': 1.10848,
#                            'y1': 1.10758,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4178,
#                            'x1': 4211,
#                            'xref': 'x',
#                            'y0': 1.10535,
#                            'y1': 1.104,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4314,
#                            'x1': 4317,
#                            'xref': 'x',
#                            'y0': 1.10488,
#                            'y1': 1.10381,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4736,
#                            'x1': 4744,
#                            'xref': 'x',
#                            'y0': 1.10377,
#                            'y1': 1.10171,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4746,
#                            'x1': 4766,
#                            'xref': 'x',
#                            'y0': 1.10303,
#                            'y1': 1.09609,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 4771,
#                            'x1': 4787,
#                            'xref': 'x',
#                            'y0': 1.09679,
#                            'y1': 1.09587,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 7052,
#                            'x1': 7066,
#                            'xref': 'x',
#                            'y0': 1.04452,
#                            'y1': 1.04289,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 7068,
#                            'x1': 7073,
#                            'xref': 'x',
#                            'y0': 1.04247,
#                            'y1': 1.04046,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 7556,
#                            'x1': 7557,
#                            'xref': 'x',
#                            'y0': 1.09079,
#                            'y1': 1.08988,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 7628,
#                            'x1': 7636,
#                            'xref': 'x',
#                            'y0': 1.08051,
#                            'y1': 1.07964,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 7672,
#                            'x1': 7673,
#                            'xref': 'x',
#                            'y0': 1.07907,
#                            'y1': 1.07807,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8298,
#                            'x1': 8306,
#                            'xref': 'x',
#                            'y0': 1.1290499999999999,
#                            'y1': 1.12822,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8399,
#                            'x1': 8400,
#                            'xref': 'x',
#                            'y0': 1.13095,
#                            'y1': 1.13013,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8743,
#                            'x1': 8744,
#                            'xref': 'x',
#                            'y0': 1.13147,
#                            'y1': 1.1304400000000001,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 8745,
#                            'x1': 8749,
#                            'xref': 'x',
#                            'y0': 1.13266,
#                            'y1': 1.13177,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9130,
#                            'x1': 9137,
#                            'xref': 'x',
#                            'y0': 1.14765,
#                            'y1': 1.14601,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9423,
#                            'x1': 9426,
#                            'xref': 'x',
#                            'y0': 1.17351,
#                            'y1': 1.1694,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9449,
#                            'x1': 9469,
#                            'xref': 'x',
#                            'y0': 1.17066,
#                            'y1': 1.16911,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9537,
#                            'x1': 9545,
#                            'xref': 'x',
#                            'y0': 1.16855,
#                            'y1': 1.16712,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9795,
#                            'x1': 9797,
#                            'xref': 'x',
#                            'y0': 1.1591,
#                            'y1': 1.15828,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9807,
#                            'x1': 9808,
#                            'xref': 'x',
#                            'y0': 1.15461,
#                            'y1': 1.15228,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 9832,
#                            'x1': 9833,
#                            'xref': 'x',
#                            'y0': 1.14804,
#                            'y1': 1.14688,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 10283,
#                            'x1': 10299,
#                            'xref': 'x',
#                            'y0': 1.16425,
#                            'y1': 1.16337,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 10719,
#                            'x1': 10724,
#                            'xref': 'x',
#                            'y0': 1.17583,
#                            'y1': 1.17483,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': 11028,
#                            'x1': 11032,
#                            'xref': 'x',
#                            'y0': 1.16338,
#                            'y1': 1.16218,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700}
# })

# %%
pf.plot_cum_returns()
# Out:
# FigureWidget({
#     'data': [{'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '46daf0ec-39fd-4d49-8c39-7c286197b2f5',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1.        , 0.99936614, 0.99952008, ..., 1.04715939, 1.04763931,
#                           1.04756687])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '65f668dc-a423-40fd-8afe-770278186f84',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1, 1, 1, ..., 1, 1, 1])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '69652036-f19d-42ee-b84e-4cb8a088441e',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1.        , 1.        , 1.        , ..., 1.03248425, 1.03248425,
#                           1.03248425])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '2074f588-90a2-43d7-b53f-c68bf1750b70',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1, 1, 1, ..., 1, 1, 1])},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '140aebbb-c46d-41f9-a146-5fc40af9d17d',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1., 1., 1., ..., 1., 1., 1.])},
#              {'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8b35fc0e-9170-4a30-b3d7-fe0fd9bd3645',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1.        , 1.        , 1.        , ..., 1.03248425, 1.03248425,
#                           1.03248425])},
#              {'hoverinfo': 'skip',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '43fc5e34-8e92-4490-bb5d-e5cf9b7d6cd2',
#               'x': array([    0,     1,     2, ..., 11421, 11422, 11423], dtype=int64),
#               'y': array([1, 1, 1, ..., 1, 1, 1])}],
#     'layout': {'height': 350,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.02,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0,
#                            'x1': 1,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y'}],
#                'template': '...',
#                'width': 700}
# })

# %%
from metalib.metaob import MetaOrderBlock

# %%
test = MetaOrderBlock(["EURUSD"], mt5.TIMEFRAME_H1, "test_ob", 0.01)

# %%
test.fit()
# Out:
# test_ob:: No model to fit for MetaOrderBlock

# %%
start_date = datetime(2025, 9, 1)
end_date = datetime(
test.signals()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 test.signals()
#
# File ~\Documents\GitHub\metalib\metalib\metaob.py:45, in MetaOrderBlock.signals(self)
#      43 def signals(self):
#      44     """Generate trading signals based on order blocks and pivot breakouts"""
# ---> 45     ohlc = self.data[self.symbols[0]]
#      47     # Calculate indicators
#      48     indicators = self.calculate_indicators(ohlc)
#
# KeyError: 'EURUSD'

# %%
from datetime import datetime, timedelta
import pytz

# %%
end_time = datetime.now(pytz.utc)
start_time = end_time - timedelta(days=90)

try:
    test.run(start_time, end_time)
except Exception as e:
    print(f"Error running strategy: {e}")
# Out:
# C:\Users\Trismegist\anaconda3\envs\adonys\lib\site-packages\tables\path.py:137: NaturalNameWarning: object name is not a valid Python identifier: '2'; it does not match the pattern ``^[a-zA-Z_][a-zA-Z0-9_]*$``; you will not be able to use natural naming to access this object; using ``getattr()`` will still work, though
#   check_attribute_name(name)
# C:\Users\Trismegist\Documents\GitHub\metalib\metalib\metastrategy.py:98: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block0_values] [items->Index(['close', 'sma_short', 'sma_long', 'uptrend', 'pivot_low', 'pivot_high',
#        'atr', 'bull_ob', 'bear_ob', 'cross_below_pivot', 'cross_above_pivot',
#        'timestamp', 'long_signal', 'short_signal'],
#       dtype='object')]
#
#   store.put(day_group, updated_data)

# %%
test.loadData(start_time, end_time)
test.debug=True

# %%
test.signals()

# %%
test.data
# Out:
# {'EURUSD':                         open     high      low    close  tick_volume  spread  \
#  time
#  2025-08-11 00:00:00  1.16400  1.16476  1.16400  1.16430          345      27
#  2025-08-11 01:00:00  1.16436  1.16509  1.16422  1.16466         1023       3
#  2025-08-11 02:00:00  1.16468  1.16507  1.16444  1.16473          804       2
#  2025-08-11 03:00:00  1.16473  1.16484  1.16418  1.16474         1466       2
#  2025-08-11 04:00:00  1.16474  1.16588  1.16454  1.16588         1480       2
#  ...                      ...      ...      ...      ...          ...     ...
#  2025-11-07 19:00:00  1.15777  1.15822  1.15715  1.15803         1680       0
#  2025-11-07 20:00:00  1.15804  1.15836  1.15675  1.15683         1355       0
#  2025-11-07 21:00:00  1.15676  1.15727  1.15556  1.15596         1761       0
#  2025-11-07 22:00:00  1.15594  1.15668  1.15574  1.15643         1499       0
#  2025-11-07 23:00:00  1.15643  1.15667  1.15584  1.15634          726       1
#
#                       real_volume
#  time
#  2025-08-11 00:00:00            0
#  2025-08-11 01:00:00            0
#  2025-08-11 02:00:00            0
#  2025-08-11 03:00:00            0
#  2025-08-11 04:00:00            0
#  ...                          ...
#  2025-11-07 19:00:00            0
#  2025-11-07 20:00:00            0
#  2025-11-07 21:00:00            0
#  2025-11-07 22:00:00            0
#  2025-11-07 23:00:00            0
#
#  [1560 rows x 7 columns]}
