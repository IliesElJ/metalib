# %%
import pandas as pd

# %%
pd.read_pickle("../historical_merged_deals.pkl")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\envs\adonys\lib\site-packages\pandas\io\pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#
# ModuleNotFoundError: No module named 'numpy._core.numeric'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.read_pickle("../historical_merged_deals.pkl")
#
# ...

# %%
import pandas as pd

try:
    # Attempt to load the pickle file
    historical_data = pd.read_pickle("../historical_merged_deals.pkl")
except ModuleNotFoundError as e:
    if "numpy._core.numeric" in str(e):
        print("Module mismatch error. Attempting to read with compatibility...")
        import pickle
        import numpy as np

        # Use custom unpickler with updated numpy module handling
        class CustomUnpickler(pickle.Unpickler):
            def find_class(self, module, name):
                if module == 'numpy._core.numeric':
                    module = 'numpy.core.numeric'
                return super().find_class(module, name)

        with open("../historical_merged_deals.pkl", "rb") as f:
            historical_data = CustomUnpickler(f).load()
    else:
        raise e

# Convert to a more portable format (e.g., CSV for future use)
historical_data.to_csv("../historical_merged_deals.csv", index=False)
print("The historical data has been loaded and saved as a CSV.")
# Out:
# Module mismatch error. Attempting to read with compatibility...
# The historical data has been loaded and saved as a CSV.

# %%
historical_data["comment_open"].unique()
# Out:
# array(['metafvg_nas', 'metaga_f2', 'metago_f1', 'metaga_i1', 'metaga_f1',
#        'metaga_i2', 'metago_f10', 'metago_f7', 'metane_btc',
#        'metago_weekly_eu', 'metane_eurusd', 'metane_dax',
#        'metago_weekly_hu', 'metane_nas', 'metago_f9'], dtype=object)
