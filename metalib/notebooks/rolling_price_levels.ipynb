# %%
from metalib.utils import load_hist_data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import vectorbt as vbt
import numpy as np

# %%
price_df = load_hist_data("AUDCHF", 2022)
price_df = price_df.iloc[:1000]
# Out:
# C:\Users\Trismegist\anaconda3\envs\adonys\lib\site-packages\pandas\core\indexes\base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)

# %%
def retrieve_top

# %%
fig, ax = plt.subplots()

price_df.close.rolling(200).median().plot(ax=ax)
price_df.close.rolling(100).median().plot(ax=ax)
price_df.close.rolling(50).median().plot(ax=ax)
price_df.close.plot(ax=ax)

plt.show()

# %%
price_df.close.round(4).value_counts().sort_values(ascending=False)
# Out:
# close
# 0.6629    78
# 0.6630    75
# 0.6627    64
# 0.6626    63
# 0.6628    52
# 0.6610    45
# 0.6635    39
# 0.6631    36
# 0.6632    34
# 0.6609    34
# 0.6611    31
# 0.6622    27
# 0.6633    26
# 0.6634    25
# 0.6612    25
# 0.6613    23
# 0.6625    23
# 0.6624    22
# 0.6636    22
# 0.6614    19
# 0.6608    19
# 0.6607    19
# 0.6619    18
# 0.6616    17
# 0.6606    17
# 0.6617    16
# 0.6621    16
# 0.6623    16
# 0.6620    15
# 0.6601    12
# 0.6605    12
# 0.6618     8
# 0.6615     8
# 0.6637     7
# 0.6642     7
# 0.6643     6
# 0.6604     6
# 0.6640     4
# 0.6639     3
# 0.6603     3
# 0.6644     2
# 0.6638     2
# 0.6602     2
# 0.6641     1
# 0.6600     1
# Name: count, dtype: int64

# %%
price_df.close.roun
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 price_df.close.round(4).plot.dist()
#       2 plt.show()
#
# AttributeError: 'PlotAccessor' object has no attribute 'dist'

# %%
.
